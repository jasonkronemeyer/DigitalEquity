# %%
# You will need a us census API key stored securely to run the census functions.

us_census_api_key = ''

# %%
# %matplotlib inline

from datetime import datetime

# Force GeoPandas pre version 0.14 to use Shapely by default instead of PyGEOS
import os
os.environ['USE_PYGEOS'] = '0'

import sys

import requests
print("Python version:", sys.version)

import geopandas as gp
print("GeoPandas version:", gp.__version__)
import matplotlib
print("matplotlib version: ", matplotlib.__version__)
import matplotlib.pyplot as plt
import pandas as pd
print("Pandas version:", pd.__version__)
import numpy as np
print("Numpy version: ", np.__version__)

import shapely
print("Shapely version: ", shapely.__version__)
from shapely.geometry import Point, Polygon
from adjustText import adjust_text
# Out:
# Python version: 3.12.2 | packaged by Anaconda, Inc. | (main, Feb 27 2024, 17:35:02) [GCC 11.2.0]
# GeoPandas version: 0.14.2
# matplotlib version:  3.8.0
# Pandas version: 2.2.1
# Numpy version:  1.26.4
# Shapely version:  2.0.1

# %%
data_loc = "./DATA/"

# %%
#open MI Puplic Land Survey Sections
eup_sections = gp.read_file(data_loc + 'MI/Sections-Counties-17-48-49/Public_Land_Survey_Sections.shp')

#open MI Public Land Survey Quarter Qaarter Sections
eup_qq_sections = gp.read_file(data_loc + 'MI/QQSections-Counties-17-48-49/Public_Land_Survey_Quarter-Quarter_Sections.shp')

# %%
len(eup_sections)
# Out:
# 4044

# %%
eup_qq_sections.plot(figsize=(32,16), color='#FFCB05')
# Out:
# <Axes: >

# %%
eup_qq_sections.columns
# Out:
# Index(['OBJECTID_1', 'OBJECTID', 'michigan_M', 'PERIMETER', 'QQS_SW_',
#        'QQS_SW_ID', 'COUNTY', 'RANGE', 'TOWN', 'SECTION', 'QTR_QTR', 'QTR',
#        'TWNRNG', 'TWNRNGSEC', 'GEO_ID', 'CNTY2', 'FORTY', 'GOV_LOT', 'CLAIM',
#        'OTHER', 'X_COORD', 'Y_COORD', 'OWNERSHIP', 'ESACONCERN', 'ICOMAPATTR',
#        'Shape_STAr', 'Shape_STLe', 'ShapeSTAre', 'ShapeSTLen', 'geometry'],
#       dtype='object')

# %%
eup_qq_sections = eup_qq_sections[['OBJECTID', 'GEO_ID', 'COUNTY', 'geometry']]

# %%
len(eup_qq_sections)
# Out:
# 60701

# %%
FCC_EUP_BSL_df = pd.read_csv(data_loc + 'FCC/Fabric_BSL_rel4/FCC_Active_BSL_12312023_rel_4.csv')
# Out:
# /tmp/ipykernel_128/4026336224.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   FCC_EUP_BSL_df = pd.read_csv(data_loc + 'FCC/Fabric_BSL_rel4/FCC_Active_BSL_12312023_rel_4.csv')

# %%
FCC_EUP_BSL_df.columns
# Out:
# Index(['location_id', 'address_primary', 'city', 'state', 'zip', 'zip_suffix',
#        'unit_count', 'bsl_flag', 'building_type_code', 'land_use_code',
#        'address_confidence_code', 'county_geoid', 'block_geoid', 'h3_9',
#        'latitude', 'longitude', 'fcc_rel'],
#       dtype='object')

# %%
FCC_EUP_BSL_df["county_geoid"].unique()
# Out:
# array([26153, 26095, 26103, 26097, 26003, 26041, 26033])

# %%
filter_vals = [26095, 26097, 26033]
filtered_df = FCC_EUP_BSL_df[FCC_EUP_BSL_df['county_geoid'].isin(filter_vals)]

# %%
filtered_df
# Out:
#        location_id                   address_primary       city state  \
# 28      1057525833                     500 VULCAN ST   NEWBERRY    MI
# 29      1057525834                   571 PARMALEE ST   NEWBERRY    MI
# 30      1057525835                 6151 TRILLIUM TRL   NEWBERRY    MI
# 31      1057525836                     7431 GRACE ST  MC MILLAN    MI
# 32      1057525838              210 W JOHN ST BLDG 2   NEWBERRY    MI
# ...            ...                               ...        ...   ...
# 82670   1453779449                  20599 S LIBBY RD   PICKFORD    MI
# 82671   1453779524                6859 E GOGOMAIN RD   PICKFORD    MI
# 82672   1453779525                6861 E GOGOMAIN RD   PICKFORD    MI
# 82673   1490273640                            BLDG R  KINCHELOE   NaN
# 82674   1490273641  4558 W INDUSTRIAL PARK DR BLDG R  KINCHELOE    MI
#
#            zip zip_suffix  unit_count  bsl_flag building_type_code  \
# 28     49868.0        NaN           1      True                  R
# 29     49868.0        NaN           1      True                  R
# 30     49868.0       8151           1      True                  R
# 31     49853.0        NaN           1      True                  R
# 32     49868.0       1125           2      True                  X
# ...        ...        ...         ...       ...                ...
# 82670  49774.0        NaN           1      True                  B
# 82671  49774.0        NaN           1      True                  R
# 82672  49774.0        NaN           1      True                  R
# 82673  49788.0        NaN           1      True                  R
# 82674  49788.0        NaN           1      True                  R
#
#        land_use_code  address_confidence_code  county_geoid      block_geoid  \
# 28                 4                        3         26095  260959601002006
# 29                 4                        3         26095  260959601001037
# 30                 4                        2         26095  260959601003031
# 31                 4                        3         26095  260959602001238
# 32                 4                        2         26095  260959601001026
# ...              ...                      ...           ...              ...
# 82670              2                        3         26033  260339710002017
# 82671              1                        3         26033  260339710002062
# 82672              1                        3         26033  260339710002062
# 82673              6                        3         26033  260339803001001
# 82674              6                        3         26033  260339802001000
#
#                   h3_9   latitude  longitude   fcc_rel
# 28     8927636a07bffff  46.350000 -85.502207  12312023
# 29     8927636a2b7ffff  46.351977 -85.506806  12312023
# 30     8927636ae43ffff  46.319860 -85.493039  12312023
# 31     892744a65d7ffff  46.338390 -85.689440  12312023
# 32     8927636a2b3ffff  46.355138 -85.511579  12312023
# ...                ...        ...        ...       ...
# 82670  89276ec84d3ffff  46.211889 -84.304573  12312023
# 82671  89276eca82fffff  46.159307 -84.220302  12312023
# 82672  89276eca82fffff  46.158908 -84.220252  12312023
# 82673  89276334a97ffff  46.248142 -84.455651  12312023
# 82674  89276334e3bffff  46.256318 -84.454784  12312023
#
# [35994 rows x 17 columns]

# %%
FCC_EUP_BSL_df = filtered_df.drop(['address_primary', 'city', 'state', 'zip', 'zip_suffix'], axis=1)

# %%
FCC_EUP_BSL_df
# Out:
#        location_id  unit_count  bsl_flag building_type_code  land_use_code  \
# 28      1057525833           1      True                  R              4
# 29      1057525834           1      True                  R              4
# 30      1057525835           1      True                  R              4
# 31      1057525836           1      True                  R              4
# 32      1057525838           2      True                  X              4
# ...            ...         ...       ...                ...            ...
# 82670   1453779449           1      True                  B              2
# 82671   1453779524           1      True                  R              1
# 82672   1453779525           1      True                  R              1
# 82673   1490273640           1      True                  R              6
# 82674   1490273641           1      True                  R              6
#
#        address_confidence_code  county_geoid      block_geoid  \
# 28                           3         26095  260959601002006
# 29                           3         26095  260959601001037
# 30                           2         26095  260959601003031
# 31                           3         26095  260959602001238
# 32                           2         26095  260959601001026
# ...                        ...           ...              ...
# 82670                        3         26033  260339710002017
# 82671                        3         26033  260339710002062
# 82672                        3         26033  260339710002062
# 82673                        3         26033  260339803001001
# 82674                        3         26033  260339802001000
#
#                   h3_9   latitude  longitude   fcc_rel
# 28     8927636a07bffff  46.350000 -85.502207  12312023
# 29     8927636a2b7ffff  46.351977 -85.506806  12312023
# 30     8927636ae43ffff  46.319860 -85.493039  12312023
# 31     892744a65d7ffff  46.338390 -85.689440  12312023
# 32     8927636a2b3ffff  46.355138 -85.511579  12312023
# ...                ...        ...        ...       ...
# 82670  89276ec84d3ffff  46.211889 -84.304573  12312023
# 82671  89276eca82fffff  46.159307 -84.220302  12312023
# 82672  89276eca82fffff  46.158908 -84.220252  12312023
# 82673  89276334a97ffff  46.248142 -84.455651  12312023
# 82674  89276334e3bffff  46.256318 -84.454784  12312023
#
# [35994 rows x 12 columns]

# %%
FCC_USUF_df = pd.read_csv(data_loc + 'FCC/MI_unserved_unfunded_mar2024.csv')

# %%
len(FCC_USUF_df)
# Out:
# 1183300

# %%
merged_df = pd.merge(FCC_EUP_BSL_df, FCC_USUF_df, how='inner', on='location_id')

# %%
len(merged_df)
# Out:
# 14237

# %%
#Add geomety to merged data Frame
usuf_location_df = gp.GeoDataFrame(
    merged_df, crs=4326, geometry=gp.points_from_xy(merged_df.longitude, merged_df.latitude))

# %%
usuf_location_df.plot(figsize=(32,16), color='#000000')
# Out:
# <Axes: >

# %%
USAC_deployment_df = pd.read_csv(data_loc + 'USAC/USAC-EUP-Deployment-0923.csv')

# %%
USAC_deployment_gdf = gp.GeoDataFrame(
    USAC_deployment_df, crs=4326, geometry=gp.points_from_xy(USAC_deployment_df.Longitude, USAC_deployment_df.Latitude))

# %%
USAC_deployment_gdf.head()
# Out:
#    Fund  Study Area Code                   Company Name              Carrier  \
# 0  ACAM           310713  HIAWATHA COMMUNICATIONS, INC.      HIAWATHA TEL CO
# 1  ACAM           310713  HIAWATHA COMMUNICATIONS, INC.      HIAWATHA TEL CO
# 2  ACAM           310713  HIAWATHA COMMUNICATIONS, INC.      HIAWATHA TEL CO
# 3  ACAM           310713  HIAWATHA COMMUNICATIONS, INC.      HIAWATHA TEL CO
# 4  ACAM           310732               LICT CORPORATION  UPPER PENINSULA TEL
#
#     Latitude  Longitude     Deployment Address  Deployment City  \
# 0  46.375698 -84.725617         8990 S LILLIAN          BRIMLEY
# 1  46.592912 -85.037149     5966 STATE HWY 123         PARADISE
# 2  46.768482 -85.002515  30714 W W CEMETARY RD         PARADISE
# 3  46.674095 -85.949658       E 22474 BAILY RD     GRAND MARAIS
# 4  46.007051 -83.863520   34980 S DIX POINT RD  DRUMMOND ISLAND
#
#   Deployment State  Deployment ZIP Code  ... Deployment Date Filing Year  \
# 0               MI                49715  ...      10/01/2007        2016
# 1               MI                49768  ...      10/01/2006        2016
# 2               MI                49768  ...      10/01/2006        2016
# 3               MI                49839  ...      10/01/2006        2016
# 4               MI                49726  ...      12/31/2015        2016
#
#       Census Block  Locations Deployed  Download/Upload Speed Tier Technology  \
# 0  260339706003272                   1              10 Mbps/1 Mbps        NaN
# 1  260339707001136                   1            100 Mbps/25 Mbps        NaN
# 2  260339707001001                   1            100 Mbps/25 Mbps        NaN
# 3  260030001001070                   1              10 Mbps/1 Mbps        NaN
# 4  260339711001027                   1              10 Mbps/1 Mbps        NaN
#
#   Other Technology  Latency Overlapping Locations                    geometry
# 0              NaN      NaN                 False  POINT (-84.72562 46.37570)
# 1              NaN      NaN                 False  POINT (-85.03715 46.59291)
# 2              NaN      NaN                 False  POINT (-85.00252 46.76848)
# 3              NaN      NaN                 False  POINT (-85.94966 46.67410)
# 4              NaN      NaN                 False  POINT (-83.86352 46.00705)
#
# [5 rows x 21 columns]

# %%
USAC_deployment_gdf['Fund'].unique()
# Out:
# array(['ACAM', 'CAF II', 'CAF II Auc', 'RDOF'], dtype=object)

# %%
# Out:
# array(['HIAWATHA TEL CO', 'UPPER PENINSULA TEL', 'CHATHAM TEL CO - MI',
#        'BRIGHTSPEED OF MICHIGAN, INC', 'MICHIGAN BELL TEL CO',
#        'GREAT LAKES ENERGY CONNECTIONS, INC.'], dtype=object)

# %%
eup_counties = gp.read_file(data_loc + 'MI/EUPCounties.shp.zip')
eup_towns = gp.read_file(data_loc + 'MI/EUPTowns.shp.zip')
#eup_towns = eup_towns[['FIPSCODE', 'geometry']]

# %%
eup_counties.plot()
# Out:
# <Axes: >

# %%
#eup_towns eup_qq_sections
# joined_df = gp.sjoin(eup_qq_sections, eup_towns, how='inner', predicate ='intersects')

# %%
#joined_df.columns
# Out:
# Index(['OBJECTID_left', 'GEO_ID', 'COUNTY', 'geometry', 'index_right',
#        'OBJECTID_right', 'FIPSCODE', 'FIPSNUM', 'NAME', 'LABEL', 'TYPE',
#        'SQKM', 'SQMILES', 'ACRES', 'VER', 'LAYOUT', 'PENINSULA', 'ShapeSTAre',
#        'ShapeSTLen'],
#       dtype='object')

# %%
#joined_df['NAME'].unique().tolist()
# Out:
# ['Whitefish',
#  'McMillan',
#  'Sugar Island',
#  'Sault Ste Marie',
#  'Columbus',
#  'Soo',
#  'Bay Mills',
#  'Bruce',
#  'Superior',
#  'Dafter',
#  'Chippewa',
#  'Hulbert',
#  'Kinross',
#  'Pentland',
#  'Lakefield',
#  'Pickford',
#  'Rudyard',
#  'Trout Lake',
#  'Raber',
#  'Hendricks',
#  'Hudson',
#  'Garfield',
#  'Portage',
#  'Marquette',
#  'St Ignace',
#  'Brevort',
#  'Moran',
#  'Newton',
#  'Drummond',
#  'Clark',
#  'Detour',
#  'Mackinac Island',
#  'Bois Blanc']

# %%
#joined_df = joined_df[~joined_df["NAME"].isin(['Seney', 'Mueller', 'Germfask'])]

# %%
EUP_Town_FIPS_list = joined_df['FIPSCODE'].unique().tolist()

# %%
eup_towns = eup_towns[eup_towns['FIPSCODE'].isin(EUP_Town_FIPS_list)]

# %%
eup_towns
# Out:
#       OBJECTID FIPSCODE  FIPSNUM             NAME                    LABEL  \
# 155        156    86700    86700        Whitefish       Whitefish Township
# 156        157    77020    77020     Sugar Island    Sugar Island Township
# 157        158    06070     6070        Bay Mills       Bay Mills Township
# 158        159    74620    74620              Soo             Soo Township
# 159        160    77540    77540         Superior        Superior Township
# 160        161    11280    11280            Bruce           Bruce Township
# 161        162    19540    19540           Dafter          Dafter Township
# 162        163    15560    15560         Chippewa        Chippewa Township
# 163        164    39860    39860          Hulbert         Hulbert Township
# 164        165    43480    43480          Kinross         Kinross Township
# 165        166    63980    63980         Pickford        Pickford Township
# 166        167    70220    70220          Rudyard         Rudyard Township
# 167        168    80600    80600       Trout Lake      Trout Lake Township
# 168        169    66760    66760            Raber           Raber Township
# 169        170    23080    23080         Drummond        Drummond Township
# 170        171    21770    21770           Detour          Detour Township
# 585        586    50440    50440         McMillan        McMillan Township
# 586        587    17480    17480         Columbus        Columbus Township
# 587        588    63500    63500         Pentland        Pentland Township
# 588        589    44540    44540        Lakefield       Lakefield Township
# 589        590    39760    39760           Hudson          Hudson Township
# 590        591    65600    65600          Portage         Portage Township
# 591        592    10360    10360          Brevort         Brevort Township
# 592        593    55480    55480            Moran           Moran Township
# 593        594    57640    57640           Newton          Newton Township
# 594        595    31620    31620         Garfield        Garfield Township
# 595        596    37660    37660        Hendricks       Hendricks Township
# 596        597    51880    51880        Marquette       Marquette Township
# 597        598    70860    70860        St Ignace       St Ignace Township
# 598        599    16060    16060            Clark           Clark Township
# 599        600    09500     9500       Bois Blanc      Bois Blanc Township
# 1265      1266    71740    71740  Sault Ste Marie  City of Sault Ste Marie
# 1336      1337    70840    70840        St Ignace        City of St Ignace
# 1337      1338    50280    50280  Mackinac Island  City of Mackinac Island
#
#           TYPE         SQKM     SQMILES          ACRES VER     LAYOUT  \
# 155   Township   636.691918  245.826995  157328.305068  20   portrait
# 156   Township   198.406177   76.604702   49026.706184  20   portrait
# 157   Township   201.455193   77.781928   49780.126269  20  landscape
# 158   Township   175.633099   67.812007   43399.416538  20  landscape
# 159   Township   271.049014  104.652129   66976.948740  20  landscape
# 160   Township   234.703035   90.618932   57995.758467  20   portrait
# 161   Township   124.101187   47.915516   30665.740849  20   portrait
# 162   Township   247.221189   95.452197   61089.028498  20  landscape
# 163   Township   185.809868   71.741262   45914.123962  20   portrait
# 164   Township   313.072212  120.877302   77360.995337  20  landscape
# 165   Township   309.646610  119.554676   76514.519875  20  landscape
# 166   Township   233.574713   90.183287   57716.947103  20  landscape
# 167   Township   371.741734  143.529627   91858.393718  20  landscape
# 168   Township   369.996120  142.855645   91427.047965  20   portrait
# 169   Township   593.014525  228.963137  146535.502582  20  landscape
# 170   Township   167.219901   64.563669   41320.492589  20  landscape
# 585   Township  1564.257763  603.960526  386532.349024  20  landscape
# 586   Township   370.550662  143.069754   91564.076732  20   portrait
# 587   Township   277.896093  107.295789   68668.880665  20  landscape
# 588   Township   186.145125   71.870705   45996.966766  20  landscape
# 589   Township   179.583278   69.337173   44375.516606  20   portrait
# 590   Township   186.958150   72.184614   46197.867384  20  landscape
# 591   Township   255.889345   98.798975   63230.953314  20   portrait
# 592   Township   344.389775  132.969025   85099.650429  20   portrait
# 593   Township   400.899884  154.787600   99063.451994  20   portrait
# 594   Township   355.930257  137.424810   87951.334787  20   portrait
# 595   Township   206.729273   79.818252   51083.365716  20   portrait
# 596   Township   251.855943   97.241677   62234.288601  20   portrait
# 597   Township   253.062273   97.707441   62532.376186  20   portrait
# 598   Township   205.244645   79.245037   50716.510130  20  landscape
# 599   Township    95.746103   36.967607   23659.122430  20  landscape
# 1265      City    52.023765   20.086396   12855.213843  20  landscape
# 1336      City     6.863055    2.649828    1695.879643  20   portrait
# 1337      City    11.090055    4.281875    2740.382842  20   portrait
#
#      PENINSULA    ShapeSTAre     ShapeSTLen  \
# 155      upper  6.366919e+08  127804.341492
# 156      upper  1.984062e+08   68523.322539
# 157      upper  2.014552e+08  100988.905151
# 158      upper  1.756331e+08   99898.197083
# 159      upper  2.710490e+08   79311.792884
# 160      upper  2.347030e+08   69213.559894
# 161      upper  1.241012e+08   51596.553276
# 162      upper  2.472212e+08   71065.847617
# 163      upper  1.858099e+08   57791.411043
# 164      upper  3.130722e+08  112747.999289
# 165      upper  3.096466e+08   93338.085639
# 166      upper  2.335747e+08   64469.000096
# 167      upper  3.717417e+08   83734.625567
# 168      upper  3.699961e+08   95774.354840
# 169      upper  5.930145e+08  187886.515050
# 170      upper  1.672199e+08   79966.806562
# 585      upper  1.564258e+09  186072.324646
# 586      upper  3.705507e+08   77016.504501
# 587      upper  2.778961e+08   77101.242222
# 588      upper  1.861451e+08   57953.493508
# 589      upper  1.795833e+08   61099.260592
# 590      upper  1.869582e+08   57997.427504
# 591      upper  2.558893e+08   67833.408437
# 592      upper  3.443898e+08  142477.241684
# 593      upper  4.008999e+08   84631.990060
# 594      upper  3.559303e+08   94514.017716
# 595      upper  2.067293e+08   80310.162654
# 596      upper  2.518559e+08   98716.936833
# 597      upper  2.530623e+08  110027.570373
# 598      upper  2.052446e+08  264494.492400
# 599      upper  9.574610e+07   58945.080744
# 1265     upper  5.202376e+07   33342.337990
# 1336     upper  6.863055e+06   18484.399867
# 1337     upper  1.109006e+07   21299.324635
#
#                                                geometry
# 155   POLYGON ((-84.98926 46.47816, -84.98928 46.477...
# 156   POLYGON ((-84.11942 46.31516, -84.12186 46.316...
# 157   MULTIPOLYGON (((-84.47575 46.45288, -84.47943 ...
# 158   POLYGON ((-84.11942 46.31516, -84.11973 46.315...
# 159   POLYGON ((-84.48895 46.41883, -84.48893 46.417...
# 160   POLYGON ((-84.17977 46.24512, -84.18376 46.245...
# 161   POLYGON ((-84.38423 46.30256, -84.39972 46.302...
# 162   POLYGON ((-84.86445 46.41838, -84.86443 46.416...
# 163   POLYGON ((-85.11459 46.41893, -85.11458 46.411...
# 164   POLYGON ((-84.38423 46.30256, -84.38396 46.296...
# 165   POLYGON ((-84.17977 46.24512, -84.17675 46.234...
# 166   POLYGON ((-84.48840 46.24490, -84.48840 46.233...
# 167   POLYGON ((-84.73774 46.15779, -84.73781 46.157...
# 168   POLYGON ((-83.95511 46.05693, -83.99987 46.063...
# 169   MULTIPOLYGON (((-83.64068 45.95005, -83.64080 ...
# 170   MULTIPOLYGON (((-83.95511 46.05693, -83.94513 ...
# 585   POLYGON ((-85.23914 46.41947, -85.23912 46.413...
# 586   POLYGON ((-85.61446 46.33164, -85.61685 46.331...
# 587   POLYGON ((-85.23783 46.24543, -85.24182 46.245...
# 588   POLYGON ((-85.61446 46.33164, -85.61423 46.310...
# 589   MULTIPOLYGON (((-85.23720 46.05978, -85.23994 ...
# 590   POLYGON ((-85.61355 46.24500, -85.61352 46.244...
# 591   POLYGON ((-84.77907 45.95475, -84.78026 45.954...
# 592   MULTIPOLYGON (((-84.92594 46.15840, -84.92582 ...
# 593   POLYGON ((-85.61344 46.01462, -85.61347 46.014...
# 594   MULTIPOLYGON (((-85.36223 46.09010, -85.36230 ...
# 595   MULTIPOLYGON (((-85.11251 46.15826, -85.11261 ...
# 596   MULTIPOLYGON (((-84.36310 46.07159, -84.37492 ...
# 597   MULTIPOLYGON (((-84.61296 46.02909, -84.61359 ...
# 598   MULTIPOLYGON (((-84.23260 45.98492, -84.23214 ...
# 599   MULTIPOLYGON (((-84.57481 45.81948, -84.57441 ...
# 1265  POLYGON ((-84.30700 46.49598, -84.30028 46.486...
# 1336  POLYGON ((-84.71696 45.84857, -84.71743 45.848...
# 1337  MULTIPOLYGON (((-84.63590 45.88310, -84.63562 ...

# %%
test_df = gp.sjoin(USAC_deployment_gdf, eup_towns, how="inner", predicate='within')

# %%
test_df.columns
# Out:
# Index(['Fund', 'Study Area Code', 'Company Name', 'Carrier', 'Latitude',
#        'Longitude', 'Deployment Address', 'Deployment City',
#        'Deployment State', 'Deployment ZIP Code', 'SAC Primary State',
#        'Deployment Date', 'Filing Year', 'Census Block', 'Locations Deployed',
#        'Download/Upload Speed Tier', 'Technology', 'Other Technology',
#        'Latency', 'Overlapping Locations', 'geometry', 'index_right',
#        'OBJECTID', 'FIPSCODE', 'FIPSNUM', 'NAME', 'LABEL', 'TYPE', 'SQKM',
#        'SQMILES', 'ACRES', 'VER', 'LAYOUT', 'PENINSULA', 'ShapeSTAre',
#        'ShapeSTLen'],
#       dtype='object')

# %%
USAC_deployment_gdf = test_df[['Fund', 'Study Area Code', 'Company Name', 'Carrier', 'Latitude',
                                'Longitude', 'Deployment Address', 'Deployment City',
                                'Deployment State', 'Deployment ZIP Code', 'SAC Primary State',
                                'Deployment Date', 'Filing Year', 'Census Block', 'Locations Deployed',
                                'Download/Upload Speed Tier', 'Technology', 'Other Technology',
                                'Latency', 'Overlapping Locations', 'FIPSCODE', 'geometry']]

# %%
USAC_deployment_gdf['Carrier'].unique()
# Out:
# array(['HIAWATHA TEL CO', 'UPPER PENINSULA TEL', 'CHATHAM TEL CO - MI',
#        'BRIGHTSPEED OF MICHIGAN, INC', 'MICHIGAN BELL TEL CO'],
#       dtype=object)

# %%
USAC_deployment_gdf['Download/Upload Speed Tier'].unique()
# Out:
# array(['10 Mbps/1 Mbps', '100 Mbps/25 Mbps', '25 Mbps/3 Mbps',
#        '4 Mbps/1 Mbps', '1 Gbps/500 Mbps'], dtype=object)

# %%
USAC_deployment_gdf.plot(figsize=(32,16), color='#000000')
# Out:
# <Axes: >

# %%
eup_towns
# Out:
#     OBJECTID FIPSCODE  FIPSNUM             NAME                    LABEL  \
# 0        156    86700    86700        Whitefish       Whitefish Township
# 1        157    77020    77020     Sugar Island    Sugar Island Township
# 2        158    06070     6070        Bay Mills       Bay Mills Township
# 3        159    74620    74620              Soo             Soo Township
# 4        160    77540    77540         Superior        Superior Township
# 5        161    11280    11280            Bruce           Bruce Township
# 6        162    19540    19540           Dafter          Dafter Township
# 7        163    15560    15560         Chippewa        Chippewa Township
# 8        164    39860    39860          Hulbert         Hulbert Township
# 9        165    43480    43480          Kinross         Kinross Township
# 10       166    63980    63980         Pickford        Pickford Township
# 11       167    70220    70220          Rudyard         Rudyard Township
# 12       168    80600    80600       Trout Lake      Trout Lake Township
# 13       169    66760    66760            Raber           Raber Township
# 14       170    23080    23080         Drummond        Drummond Township
# 15       171    21770    21770           Detour          Detour Township
# 16       586    50440    50440         McMillan        McMillan Township
# 17       587    17480    17480         Columbus        Columbus Township
# 18       588    63500    63500         Pentland        Pentland Township
# 19       589    44540    44540        Lakefield       Lakefield Township
# 20       590    39760    39760           Hudson          Hudson Township
# 21       591    65600    65600          Portage         Portage Township
# 22       592    10360    10360          Brevort         Brevort Township
# 23       593    55480    55480            Moran           Moran Township
# 24       594    57640    57640           Newton          Newton Township
# 25       595    31620    31620         Garfield        Garfield Township
# 26       596    37660    37660        Hendricks       Hendricks Township
# 27       597    51880    51880        Marquette       Marquette Township
# 28       598    70860    70860        St Ignace       St Ignace Township
# 29       599    16060    16060            Clark           Clark Township
# 30       600    09500     9500       Bois Blanc      Bois Blanc Township
# 31      1266    71740    71740  Sault Ste Marie  City of Sault Ste Marie
# 32      1337    70840    70840        St Ignace        City of St Ignace
# 33      1338    50280    50280  Mackinac Island  City of Mackinac Island
#
#         TYPE         SQKM     SQMILES          ACRES VER     LAYOUT PENINSULA  \
# 0   Township   636.691918  245.826995  157328.305068  20   portrait     upper
# 1   Township   198.406177   76.604702   49026.706184  20   portrait     upper
# 2   Township   201.455193   77.781928   49780.126269  20  landscape     upper
# 3   Township   175.633099   67.812007   43399.416538  20  landscape     upper
# 4   Township   271.049014  104.652129   66976.948740  20  landscape     upper
# 5   Township   234.703035   90.618932   57995.758467  20   portrait     upper
# 6   Township   124.101187   47.915516   30665.740849  20   portrait     upper
# 7   Township   247.221189   95.452197   61089.028498  20  landscape     upper
# 8   Township   185.809868   71.741262   45914.123962  20   portrait     upper
# 9   Township   313.072212  120.877302   77360.995337  20  landscape     upper
# 10  Township   309.646610  119.554676   76514.519875  20  landscape     upper
# 11  Township   233.574713   90.183287   57716.947103  20  landscape     upper
# 12  Township   371.741734  143.529627   91858.393718  20  landscape     upper
# 13  Township   369.996120  142.855645   91427.047965  20   portrait     upper
# 14  Township   593.014525  228.963137  146535.502582  20  landscape     upper
# 15  Township   167.219901   64.563669   41320.492589  20  landscape     upper
# 16  Township  1564.257763  603.960526  386532.349024  20  landscape     upper
# 17  Township   370.550662  143.069754   91564.076732  20   portrait     upper
# 18  Township   277.896093  107.295789   68668.880665  20  landscape     upper
# 19  Township   186.145125   71.870705   45996.966766  20  landscape     upper
# 20  Township   179.583278   69.337173   44375.516606  20   portrait     upper
# 21  Township   186.958150   72.184614   46197.867384  20  landscape     upper
# 22  Township   255.889345   98.798975   63230.953314  20   portrait     upper
# 23  Township   344.389775  132.969025   85099.650429  20   portrait     upper
# 24  Township   400.899884  154.787600   99063.451994  20   portrait     upper
# 25  Township   355.930257  137.424810   87951.334787  20   portrait     upper
# 26  Township   206.729273   79.818252   51083.365716  20   portrait     upper
# 27  Township   251.855943   97.241677   62234.288601  20   portrait     upper
# 28  Township   253.062273   97.707441   62532.376186  20   portrait     upper
# 29  Township   205.244645   79.245037   50716.510130  20  landscape     upper
# 30  Township    95.746103   36.967607   23659.122430  20  landscape     upper
# 31      City    52.023765   20.086396   12855.213843  20  landscape     upper
# 32      City     6.863055    2.649828    1695.879643  20   portrait     upper
# 33      City    11.090055    4.281875    2740.382842  20   portrait     upper
#
#       ShapeSTAre     ShapeSTLen  \
# 0   6.366919e+08  127804.341492
# 1   1.984062e+08   68523.322539
# 2   2.014552e+08  100988.905151
# 3   1.756331e+08   99898.197083
# 4   2.710490e+08   79311.792884
# 5   2.347030e+08   69213.559894
# 6   1.241012e+08   51596.553276
# 7   2.472212e+08   71065.847617
# 8   1.858099e+08   57791.411043
# 9   3.130722e+08  112747.999289
# 10  3.096466e+08   93338.085639
# 11  2.335747e+08   64469.000096
# 12  3.717417e+08   83734.625567
# 13  3.699961e+08   95774.354840
# 14  5.930145e+08  187886.515050
# 15  1.672199e+08   79966.806562
# 16  1.564258e+09  186072.324646
# 17  3.705507e+08   77016.504501
# 18  2.778961e+08   77101.242222
# 19  1.861451e+08   57953.493508
# 20  1.795833e+08   61099.260592
# 21  1.869582e+08   57997.427504
# 22  2.558893e+08   67833.408437
# 23  3.443898e+08  142477.241684
# 24  4.008999e+08   84631.990060
# 25  3.559303e+08   94514.017716
# 26  2.067293e+08   80310.162654
# 27  2.518559e+08   98716.936833
# 28  2.530623e+08  110027.570373
# 29  2.052446e+08  264494.492400
# 30  9.574610e+07   58945.080744
# 31  5.202376e+07   33342.337990
# 32  6.863055e+06   18484.399867
# 33  1.109006e+07   21299.324635
#
#                                              geometry
# 0   POLYGON ((-84.98926 46.47816, -84.98928 46.477...
# 1   POLYGON ((-84.11942 46.31516, -84.12186 46.316...
# 2   MULTIPOLYGON (((-84.47575 46.45288, -84.47943 ...
# 3   POLYGON ((-84.11942 46.31516, -84.11973 46.315...
# 4   POLYGON ((-84.48895 46.41883, -84.48893 46.417...
# 5   POLYGON ((-84.17977 46.24512, -84.18376 46.245...
# 6   POLYGON ((-84.38423 46.30256, -84.39972 46.302...
# 7   POLYGON ((-84.86445 46.41838, -84.86443 46.416...
# 8   POLYGON ((-85.11459 46.41893, -85.11458 46.411...
# 9   POLYGON ((-84.38423 46.30256, -84.38396 46.296...
# 10  POLYGON ((-84.17977 46.24512, -84.17675 46.234...
# 11  POLYGON ((-84.48840 46.24490, -84.48840 46.233...
# 12  POLYGON ((-84.73774 46.15779, -84.73781 46.157...
# 13  POLYGON ((-83.95511 46.05693, -83.99987 46.063...
# 14  MULTIPOLYGON (((-83.64068 45.95005, -83.64080 ...
# 15  MULTIPOLYGON (((-83.95511 46.05693, -83.94513 ...
# 16  POLYGON ((-85.23914 46.41947, -85.23912 46.413...
# 17  POLYGON ((-85.61446 46.33164, -85.61685 46.331...
# 18  POLYGON ((-85.23783 46.24543, -85.24182 46.245...
# 19  POLYGON ((-85.61446 46.33164, -85.61423 46.310...
# 20  MULTIPOLYGON (((-85.23720 46.05978, -85.23994 ...
# 21  POLYGON ((-85.61355 46.24500, -85.61352 46.244...
# 22  POLYGON ((-84.77907 45.95475, -84.78026 45.954...
# 23  MULTIPOLYGON (((-84.92594 46.15840, -84.92582 ...
# 24  POLYGON ((-85.61344 46.01462, -85.61347 46.014...
# 25  MULTIPOLYGON (((-85.36223 46.09010, -85.36230 ...
# 26  MULTIPOLYGON (((-85.11251 46.15826, -85.11261 ...
# 27  MULTIPOLYGON (((-84.36310 46.07159, -84.37492 ...
# 28  MULTIPOLYGON (((-84.61296 46.02909, -84.61359 ...
# 29  MULTIPOLYGON (((-84.23260 45.98492, -84.23214 ...
# 30  MULTIPOLYGON (((-84.57481 45.81948, -84.57441 ...
# 31  POLYGON ((-84.30700 46.49598, -84.30028 46.486...
# 32  POLYGON ((-84.71696 45.84857, -84.71743 45.848...
# 33  MULTIPOLYGON (((-84.63590 45.88310, -84.63562 ...

# %%
eup_towns.plot(color='blue')
# Out:
# <Axes: >

# %%
eup_towns.to_file(data_loc + 'MI/EUPTowns.shp.zip', driver='ESRI Shapefile')

# %%
eup_counties
# Out:
#   FIPSCODE                                           geometry
# 0      033  MULTIPOLYGON (((-83.93101 46.05865, -83.92995 ...
# 1      095  POLYGON ((-85.86468 46.28084, -85.86462 46.281...
# 2      097  MULTIPOLYGON (((-84.36273 45.99577, -84.36275 ...

# %%
def query_digital_equity_data(api_key, state, county):
    """
    Queries digital equity data from the US Census ACS API.

    Args:
        api_key (str): Your Census API key.
        state (str): State code (e.g., '26' for Michigan).
        county (str): County (e.g., '095').

    Returns:
        dataframe: Digital equity data (e.g., internet access, computer ownership, etc.).
    """
    base_url = "https://api.census.gov/data/2022/acs/acs5"
    variables = {
        "NAME": "name",
        "B01001_001E": "B01001_001E",
        "B28002_001E": "total_households",
        "B28002_002E": "with_computer",
        "B28002_003E": "with_internet",
        "B28002_004E": "with_broadband",        
    }

    params = {
        "get": ",".join(variables.keys()),
        "for": "county subdivision:*",
        "in": "state:" + state + " county:" + county,
        "key": api_key,
    }
    #print(params)

    response = requests.get(base_url, params=params)
    #print(response)
    data = response.json()
    data = pd.DataFrame(data)
    data.columns = data.iloc[0]
    data = data[~data["county subdivision"].isin(['00000', 'county subdivision'])]
    data.rename(columns={'county subdivision': 'FIPSCODE'},inplace=True)

    if "error" in data:
        raise Exception(f"Error fetching data: {data['error'][0]}")

    return data

# %%
if __name__ == "__main__":
    api_key = us_census_api_key
    state_code = "26"
    county = "033,095,097"

    try:
        digital_equity_data = query_digital_equity_data(api_key, state_code, county)
        print("Digital Equity Data:")
        # for key, value in digital_equity_data.items():
        #     print(f"{key}: {value}")
        #print(digital_equity_data)
    except Exception as e:
        print(f"Error: {e}")
# Out:
# Digital Equity Data:

# %%
#digital_equity_data.columns = digital_equity_data.iloc[0]

# %%
#digital_equity_data = digital_equity_data[~digital_equity_data["county subdivision"].isin(['00000', 'county subdivision'])]

# %%
#digital_equity_data = digital_equity_data
digital_equity_data
# Out:
# 0                                                NAME B01001_001E B28002_001E  \
# 2       Bay Mills township, Chippewa County, Michigan        1821         736
# 3           Bruce township, Chippewa County, Michigan        1982         785
# 4        Chippewa township, Chippewa County, Michigan         298         119
# 5          Dafter township, Chippewa County, Michigan        1490         478
# 6          Detour township, Chippewa County, Michigan         632         306
# 7        Drummond township, Chippewa County, Michigan        1001         541
# 8         Hulbert township, Chippewa County, Michigan         161          82
# 9   Kinross charter township, Chippewa County, Mic...        7069        1418
# 10       Pickford township, Chippewa County, Michigan        1511         592
# 11          Raber township, Chippewa County, Michigan         556         274
# 12        Rudyard township, Chippewa County, Michigan        1141         465
# 13   Sault Ste. Marie city, Chippewa County, Michigan       13409        5787
# 14            Soo township, Chippewa County, Michigan        2997        1093
# 15   Sugar Island township, Chippewa County, Michigan         571         275
# 16       Superior township, Chippewa County, Michigan        1411         484
# 17     Trout Lake township, Chippewa County, Michigan         137          80
# 18      Whitefish township, Chippewa County, Michigan         483         232
# 20           Columbus township, Luce County, Michigan         181          87
# 21          Lakefield township, Luce County, Michigan         956         486
# 22           McMillan township, Luce County, Michigan        1964         963
# 23           Pentland township, Luce County, Michigan        2341         529
# 25     Bois Blanc township, Mackinac County, Michigan          44          22
# 26        Brevort township, Mackinac County, Michigan         568         301
# 27          Clark township, Mackinac County, Michigan        1830         926
# 28       Garfield township, Mackinac County, Michigan        1383         543
# 29      Hendricks township, Mackinac County, Michigan         138          76
# 30         Hudson township, Mackinac County, Michigan         207         105
# 31    Mackinac Island city, Mackinac County, Michigan         836         344
# 32      Marquette township, Mackinac County, Michigan         601         280
# 33          Moran township, Mackinac County, Michigan         854         433
# 34         Newton township, Mackinac County, Michigan         380         215
# 35        Portage township, Mackinac County, Michigan         816         432
# 36         St. Ignace city, Mackinac County, Michigan        2233        1076
# 37     St. Ignace township, Mackinac County, Michigan         953         473
#
# 0  B28002_002E B28002_003E B28002_004E state county FIPSCODE
# 2          656           0         656    26    033    06070
# 3          708           0         708    26    033    11280
# 4           90           1          89    26    033    15560
# 5          382           0         382    26    033    19540
# 6          257           2         255    26    033    21770
# 7          486           0         486    26    033    23080
# 8           68           0          68    26    033    39860
# 9         1299           0        1299    26    033    43480
# 10         524           3         521    26    033    63980
# 11         196          14         182    26    033    66760
# 12         389           0         389    26    033    70220
# 13        4885           9        4876    26    033    71740
# 14        1023           0        1023    26    033    74620
# 15         198           0         198    26    033    77020
# 16         422           3         419    26    033    77540
# 17          52           0          52    26    033    80600
# 18         201           0         201    26    033    86700
# 20          67           0          67    26    095    17480
# 21         390           3         387    26    095    44540
# 22         769           0         769    26    095    50440
# 23         432           0         432    26    095    63500
# 25          21           0          21    26    097    09500
# 26         241           0         241    26    097    10360
# 27         781          11         770    26    097    16060
# 28         390           2         388    26    097    31620
# 29          45           2          43    26    097    37660
# 30          74           0          74    26    097    39760
# 31         310           2         308    26    097    50280
# 32         238           7         231    26    097    51880
# 33         347           0         347    26    097    55480
# 34         161           0         161    26    097    57640
# 35         336           0         336    26    097    65600
# 36         946           0         946    26    097    70840
# 37         370           0         370    26    097    70860

# %%
data2 = requests.get("https://api.census.gov/data/2022/acs/acs5?get=NAME,B01001_001E&for=county%20subdivision:*&in=state:26&in=county:097,095,033&key=" + us_census_api_key)

# %%
data2
# Out:
# <Response [200]>

# %%
data3 = data2.json()

# %%
data_df = pd.DataFrame(data3)
data_df
# Out:
#                                                     0            1      2  \
# 0                                                NAME  B01001_001E  state
# 1   County subdivisions not defined, Chippewa Coun...            0     26
# 2       Bay Mills township, Chippewa County, Michigan         1821     26
# 3           Bruce township, Chippewa County, Michigan         1982     26
# 4        Chippewa township, Chippewa County, Michigan          298     26
# 5          Dafter township, Chippewa County, Michigan         1490     26
# 6          Detour township, Chippewa County, Michigan          632     26
# 7        Drummond township, Chippewa County, Michigan         1001     26
# 8         Hulbert township, Chippewa County, Michigan          161     26
# 9   Kinross charter township, Chippewa County, Mic...         7069     26
# 10       Pickford township, Chippewa County, Michigan         1511     26
# 11          Raber township, Chippewa County, Michigan          556     26
# 12        Rudyard township, Chippewa County, Michigan         1141     26
# 13   Sault Ste. Marie city, Chippewa County, Michigan        13409     26
# 14            Soo township, Chippewa County, Michigan         2997     26
# 15   Sugar Island township, Chippewa County, Michigan          571     26
# 16       Superior township, Chippewa County, Michigan         1411     26
# 17     Trout Lake township, Chippewa County, Michigan          137     26
# 18      Whitefish township, Chippewa County, Michigan          483     26
# 19  County subdivisions not defined, Luce County, ...            0     26
# 20           Columbus township, Luce County, Michigan          181     26
# 21          Lakefield township, Luce County, Michigan          956     26
# 22           McMillan township, Luce County, Michigan         1964     26
# 23           Pentland township, Luce County, Michigan         2341     26
# 24  County subdivisions not defined, Mackinac Coun...            0     26
# 25     Bois Blanc township, Mackinac County, Michigan           44     26
# 26        Brevort township, Mackinac County, Michigan          568     26
# 27          Clark township, Mackinac County, Michigan         1830     26
# 28       Garfield township, Mackinac County, Michigan         1383     26
# 29      Hendricks township, Mackinac County, Michigan          138     26
# 30         Hudson township, Mackinac County, Michigan          207     26
# 31    Mackinac Island city, Mackinac County, Michigan          836     26
# 32      Marquette township, Mackinac County, Michigan          601     26
# 33          Moran township, Mackinac County, Michigan          854     26
# 34         Newton township, Mackinac County, Michigan          380     26
# 35        Portage township, Mackinac County, Michigan          816     26
# 36         St. Ignace city, Mackinac County, Michigan         2233     26
# 37     St. Ignace township, Mackinac County, Michigan          953     26
#
#          3                   4
# 0   county  county subdivision
# 1      033               00000
# 2      033               06070
# 3      033               11280
# 4      033               15560
# 5      033               19540
# 6      033               21770
# 7      033               23080
# 8      033               39860
# 9      033               43480
# 10     033               63980
# 11     033               66760
# 12     033               70220
# 13     033               71740
# 14     033               74620
# 15     033               77020
# 16     033               77540
# 17     033               80600
# 18     033               86700
# 19     095               00000
# 20     095               17480
# 21     095               44540
# 22     095               50440
# 23     095               63500
# 24     097               00000
# 25     097               09500
# 26     097               10360
# 27     097               16060
# 28     097               31620
# 29     097               37660
# 30     097               39760
# 31     097               50280
# 32     097               51880
# 33     097               55480
# 34     097               57640
# 35     097               65600
# 36     097               70840
# 37     097               70860

# %%
        "B28002_001E": "total_households",
        "B28002_002E": "with_computer",
        "B28002_003E": "with_internet",
        "B28002_004E": "with_broadband",

# %% [markdown]
# Background information about the **Margin of Error (MOE)** in **US Census data** with reference links included:
#
# ---
#
# ## Margin of Error (MOE) in US Census Data
#
# The **Margin of Error (MOE)** in **US Census data** is a measure of the **possible variation** of an estimate around the actual population     ns:
#
# #Estimates and Sampling:
#
#   - The **American Community Survey (ACS)** provides estimates based on a **sample** of the population.
#   - Different samples would yield different estimates of the actual population value.
#   - The MOE accounts for this va##   iability.
#
# #Certainty at a Given Confidence Level:
#
#   - Data users can be **certain** at a given **confidence level** that the estimate and the actual population value differ by no more than the value of the MOE.
#   - The confidence level is typically **90%**, but other levels (such as 95% or 99%) ca#    also be used.
#
# #Interpreting MOE:
#
#   - If an estimate is **50,000** with an MOE of **2,000**, it means that we are **90% confident** that the actual population value lies between **48,000** and **52,000**.
#   - The MOE provides a **range** within which the true#   value likely falls.
#
# #Statistical Significance:
#
#   - When comparing estimates, we use the MOE to test for **statistical significance**.
#   - If the difference between two estimates is **greater than the MOE**, they are considered **statistically different**.
#
# In summary, the MOE ensures that ACS estimates are not exact figures but rather a **range of possible values** around the population value, accounting for sampling variability.
#
# ---
#
# **References**:
# 1. [US Census Bureau - Understanding and Using American Community Survey Data: Margin of Error](https://www.census.gov/programs-surveys/acs/guidance/handbooks/general.html)
# 2. [American Community Survey (ACS) - Accuracy of the Data](https://www.census.gov/programs-ml) ys/acs/guidance/accuracy.html)
